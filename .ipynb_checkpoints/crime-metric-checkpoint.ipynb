# %% [markdown]
# # Metric: Crime
# The more safe a neighboorhood is, the more safe public parks with these sporting spaces are.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#importing data
crime = pd.read_csv("public-safety.csv")

#displaying data!
crime.head(5)
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#    #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 0                                    71                     141
# 1                                    38                      49
# 2                                   159                     252
# 3                                    50                      84
# 4                                    19                      37
#
#    #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 0                            46                                  7.6
# 1                            31                                  8.2
# 2                           160                                  6.4
# 3                            48                                  2.7
# 4                            24                                  7.8
#
#    Part 2 Crime per 100 Persons (2010)  #Murder (2010)  #Rape (2010)  \
# 0                                 15.1               0             2
# 1                                 10.6               1             0
# 2                                 10.1               0             2
# 3                                  4.5               0             1
# 4                                 15.2               0             0
#
#    #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# 0                9                     5                 8
# 1                4                     6                 6
# 2               15                    23                48
# 3                8                     5                15
# 4                4                     5                 5
#
#    #Auto Theft (2010)  #Drug Violations (2010)
# 0                   5                       31
# 1                   4                       12
# 2                  11                       66
# 3                   7                        9
# 4                   3                        7

# %%
total_crime = crime["#Murder (2010)"] + crime["#Rape (2010)"] + crime["#Robbery (2010)"] + crime["#Agr. Assault (2010)"] + crime["#Burglary (2010)"] + crime["#Auto Theft (2010)"] + crime["#Drug Violations (2010)"]
population = crime["Population (2010)"].str.replace(',', '')
population = population.astype(int)
cpp = (total_crime / population * 100)
crime["Crime/Population (%)"] = cpp

filtereds = crime.filter(["Neighborhood", "Crime/Population (%)"]).sort_values(by=["Crime/Population (%)"], ascending=False)
graph = filterds.plot.barh(x="Neighborhood", y= "Crime/Population (%)", figsize=(7,crime.shape[0] * 0.3), legend=None)
graph.set_xlabel("Crime/Population (%)")
display(graph)
